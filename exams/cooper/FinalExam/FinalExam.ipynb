# %% [markdown]
# # Final Exam - COMP 141-3 (Cooper)
#
# ## Write Code
#
# Instructions:
#
#  -> Complete the programs below (use the specified approach when listed).
#
#  -> Demonstrate their correctness by running them (use the specified test cases when listed).
#
#  -> Save your notebook (File menu > Save and Checkpoint).
#
#  -> Submit your notebook using the okpy function at the bottom.
#
#  -> Make sure that it submits successfully before logging out.
#
# **You may only submit your notebook once**

# %% [markdown]
# ### A. (10 points)

# %%
# Problem A

# %% [markdown]
# ### B. (10 points)

# %%
# Problem B

# %% [markdown]
# ### C. (15 points)

# %%
# Problem C

# %% [markdown]
# ### D. (15 points)

# %%
# Problem D

# %% [markdown]
# ### E - Part 1. (10 points)

# %%
# Problem E - Part 1

# %% [markdown]
# ### E - Part 2. (10 points)

# %%
# Problem E - Part 2

# %% [markdown]
# ### E - Part 3. (10 points)

# %%
# Problem E - Part 3

# %% [markdown]
# ### F - Part 1. (5 points)

# %%
# Problem F - Part 1

# %% [markdown]
# ### F - Part 2. (10 points)

# %%
# Problem F - Part 2

# %% [markdown]
# ### F - Part 3. (15 points)

# %%
# Problem F - Part 3

# %% [markdown]
# # Submitting
#
# To submit this portion of the midterm, run the cell below. YOU CAN ONLY SUBMIT ONCE. Make sure that you click the link returned to you by okpy to verify that your notebook submitted correctly.

# %%
# Run this cell to log in to okpy.org 
from cs1.notebooks import *
ok_login('finalexam.ok')

# %%
# Run this cell to submit
ok_submit('finalexam.ok')
