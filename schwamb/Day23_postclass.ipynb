# %% [markdown]
# # Day 23: Algorithms
#
# Algorithms are procedures that allow us to accomplish tasks methodically and efficiently.
#
# What algorithms do you know of?

# %% [markdown]
# ## Towers of Hanoi
#
# Play this game and then let's discuss how it might relate to algorithms:
# https://www.mathsisfun.com/games/towerofhanoi.html

# %% [markdown]
# ## Some common tasks algorithms are used for
# * Sorting
# * Finding a value in a data structure (e.g., a list)
# * Finding the shortest path between two points
# * Data mining
# * AI/ML (many algorithms for training models)

# %% [markdown]
# ## Practice
# Let's try and come up with some simple sorting algorithms. Let's say I have a list:
#
# `[37, 39, 14, 5, 3, 2, 24, 11, 17, 18, 42, 31, 49, 8, 27, 35, 22, 23, 8, 7, 50, 20, 49, 28, 30]`
#
# What are some ways I might go about sorting this list? (Not built-in methods list lst.sort() - what are the *algorithms* I could use to sort this list?

# %% [markdown]
# * Bubble sort (Selin)
# * Merge sort (Max)
# * Partition sort/quicksort (Ava)
# * Selection sort (Addison)
# * Insertion sort
