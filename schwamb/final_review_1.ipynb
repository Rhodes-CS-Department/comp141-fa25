# %% [markdown]
# # Final Review
# ## Final Information
# The final, like the midterm, is an oral exam. Just like the midterm, I'll send out a calendly link and you'll sign up for a slot. This time I'm making the slots 30min rather than 20min so I'll hopefully be running behind less. I'll still aim for a 20min exam, the 30min will just give me more leeway. I'll focus on topics we've covered since the midterm since I have limited time, but theoretically I could ask anything we've covered in the class.
#
# ## Final grade information
# On Canvas, there's a link to the final grade worksheet. This allows you to pick the weighting of your final grade (in conversation with me). Please come to your final time with it already filled out - you'll have to guess a bit at your grade on the final exam, but that will allow you to have both your final exam grade and your final grade in the class by the time you leave my office after the final exam. (It will likely not show up in Canvas/Workday till all the final exams have been given, but you'll know what it is.)
#
# ## What have we covered?
# * Using built-in functions (e.g., `print`)
# * Math operations (+, -, *, /, %)
# * Using library functions (e.g., `sqrt`)
# * `if`, `elif`, `else`
# * Building our own functions
# * Graphics
# * Loops (`for` and `while`)
# * Nested loops
# * File I/O
# * Lists
# * String manipulation and indexing
# * 2D Lists
# * Dictionaries
# * Binary numbers
# * Algorithms
#
# ## What examples of this would you like to see?

# %%
from cs1.graphics import *

open_canvas(500,500)
draw_circle(250,250,50)
# Out:
# AppLayout(children=(MultiCanvas(layout=Layout(grid_area='center'), sync_image_data=True, width=500),), layout=…

# %%
open_canvas(500,500)
draw_filled_circle(250,250,50)

# for button actions, use tkinter
# Out:
# AppLayout(children=(MultiCanvas(layout=Layout(grid_area='center'), sync_image_data=True, width=500),), layout=…

# %%
my_name = "Addison Leigh Schwamb"
print(my_name[0]) # displays: A
print(my_name[-1]) # displays: b
print(my_name[:7]) # displays: Addison
print(my_name[8:13]) # displays: Leigh
print(my_name.split()) # displays: ['Addison','Leigh','Schwamb']
print(my_name.split("i")) # displays: ['Add','son Le','gh Schwamb']
# Out:
# A
# b
# Addison
# Leigh
# ['Addison', 'Leigh', 'Schwamb']
# ['Add', 'son Le', 'gh Schwamb']
